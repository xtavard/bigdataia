# %%
from pathlib import Path
import pandas as pd

DATA_DIR = Path("/workspace/data/")
fichier = DATA_DIR/"referentiels"/"categories.csv"

categories=pd.read_csv(fichier,sep=";")

print(categories.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 7
#       3
#       4 DATA_DIR = Path("/workspace/data/")
#       5 fichier = DATA_DIR/"referentiels"/"categories.csv"
#       6
# ----> 7 categories=pd.read_csv(fichier,sep=";")
#       8
#       9 print(categories.head())
#
# ...
