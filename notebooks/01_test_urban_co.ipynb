# %%
from pathlib import Path
import pandas as pd

data_dir = Path("/workspace/data/raw/URBAN_CO_DATA")
fichier=data_dir/"ventes"/"ventes_2025.csv"

ventes = pd.read_csv(fichier,sep=";")

print("Dimensions :", ventes.shape)
print("\nColonnes :")
print(ventes.columns.tolist())

display(ventes.head())
# Out:
# Dimensions : (20, 17)
#
# Colonnes :
# ['vente_id', 'date', 'magasin_id', 'vendeur_id', 'client_id', 'produit_id', 'quantite', 'prix_unitaire', 'remise', 'CA', 'cout_achat_unitaire', 'campagne_id', 'retour', 'date_retour', 'motif_retour', 'mode_livraison', 'magasin_retrait']
#   vente_id        date magasin_id vendeur_id client_id produit_id  quantite  \
# 0     V001  2025-03-12       M014     VEN082     C4567      P1254         1
# 1     V002  2025-03-12       M014     VEN031     C8821      P0372         2
# 2     V003    12/03/25        WEB        WEB     C9122      P1254         1
# 3     V004  2025-03-13       M021     VEN045     C3345      P0981         1
# 4     V005  2025-03-13       M035     VEN019     C1290      P1102         1
#
#    prix_unitaire remise      CA  cout_achat_unitaire campagne_id retour  \
# 0            799    10%  719.10                  420   canapé_Q1    non
# 1             49     0%   98.00                   18         NaN    non
# ...

# %%
ventes.info()

# %%
ventes.isna().sum()
# Out:
# vente_id                0
# date                    0
# magasin_id              0
# vendeur_id              0
# client_id               0
# produit_id              0
# quantite                0
# prix_unitaire           0
# remise                  0
# CA                      0
# cout_achat_unitaire     0
# campagne_id            17
# retour                  0
# date_retour            18
# motif_retour           18
# mode_livraison          0
# magasin_retrait         4
# dtype: int64
